# %% [markdown]
# 라이브러리 설치

# %%
# !pip install numpy pandas
# Out:
# Requirement already satisfied: numpy in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (2.3.5)
# Requirement already satisfied: pandas in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# !pip install aeon
# Out:
# Requirement already satisfied: aeon in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (1.4.0)
# Requirement already satisfied: deprecated>=1.2.13 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from aeon) (1.3.1)
# Requirement already satisfied: numba<0.64.0,>=0.55 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from aeon) (0.63.1)
# Requirement already satisfied: numpy<2.5.0,>=2.0.0 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from aeon) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from aeon) (26.0)
# Requirement already satisfied: pandas<2.4.0,>=2.0.0 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from aeon) (2.3.3)
# Requirement already satisfied: scikit-learn<1.8.0,>=1.6.0 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from aeon) (1.7.2)
# Requirement already satisfied: scipy<1.18.0,>=1.9.0 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from aeon) (1.17.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from aeon) (4.15.0)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from numba<0.64.0,>=0.55->aeon) (0.46.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from pandas<2.4.0,>=2.0.0->aeon) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from pandas<2.4.0,>=2.0.0->aeon) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from pandas<2.4.0,>=2.0.0->aeon) (2026.2)
# Requirement already satisfied: joblib>=1.2.0 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from scikit-learn<1.8.0,>=1.6.0->aeon) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from scikit-learn<1.8.0,>=1.6.0->aeon) (3.6.0)
# Requirement already satisfied: wrapt<3,>=1.10 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from deprecated>=1.2.13->aeon) (2.2.1)
# Requirement already satisfied: six>=1.5 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from python-dateutil>=2.8.2->pandas<2.4.0,>=2.0.0->aeon) (1.17.0)

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from scikit-learn) (2.3.5)
# Requirement already satisfied: scipy>=1.8.0 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.2.0 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from scikit-learn) (3.6.0)

# %%
# !pip install matplotlib seaborn
# Out:
# Requirement already satisfied: matplotlib in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (3.10.9)
# Requirement already satisfied: seaborn in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from tensorflow) (26.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from tensorflow) (7.35.0)
# Requirement already satisfied: requests<3,>=2.21.0 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from tensorflow) (2.33.1)
# Requirement already satisfied: setuptools in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from tensorflow) (82.0.1)
# Requirement already satisfied: six>=1.12.0 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from tensorflow) (2.2.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from tensorflow) (1.80.0)
# Requirement already satisfied: keras>=3.12.0 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from tensorflow) (3.14.1)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from tensorflow) (2.3.5)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.5.20)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: rich in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from keras>=3.12.0->tensorflow) (15.0.0)
# Requirement already satisfied: namex in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from keras>=3.12.0->tensorflow) (0.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from rich->keras>=3.12.0->tensorflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\nyank\anaconda3\envs\aixprj\Lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)

# %% [markdown]
# 라이브러리 임포트

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 데이터 로드

# %%
from aeon.datasets import load_classification
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, auc

# %%
X, y = load_classification(name="FordA")

print(f"Train Data Shape: {X.shape}")
print(f"Test Data Shape: {y.shape}")
# Out:
# C:\Users\nyank\AppData\Local\Temp\ipykernel_5148\162285114.py:1: FutureWarning: Call to deprecated function (or staticmethod) load_classification. (load_classification parameters load_equal_length and load_no_missing will default to False in version 1.5.0) -- Deprecated since version 1.4.0.
#   X, y = load_classification(name="FordA")
# Train Data Shape: (4921, 1, 500)
# Test Data Shape: (4921,)

# %%
#타겟 클래스 변환
y = np.where(y == '-1', 'Normal', np.where(y == '1', 'Defect', y))

# %%
unique, counts = np.unique(y, return_counts=True)
class_dist = pd.DataFrame({'Class': unique, 'Count': counts})
class_dist['Percentage'] = (class_dist['Count'] / class_dist['Count'].sum()) * 100

print("-" * 40)
print(class_dist.to_string(index=False))
print("-" * 40)

plt.figure(figsize=(6, 4))
sns.barplot(data=class_dist, x='Class', y='Count', palette='Set2', hue='Class', legend=False)
plt.title("FordA Full Dataset Class Distribution", fontsize=12, fontweight='bold', color='navy')
plt.xlabel("Engine Status")
plt.ylabel("Number of Samples")
plt.grid(axis='y', linestyle='--', alpha=0.5)

for p in class_dist.index:
    count = class_dist.loc[p, 'Count']
    percent = class_dist.loc[p, 'Percentage']
    plt.text(p, count + 40, f'{percent:.1f}%', ha="center", fontsize=10, fontweight='bold')
    plt.text(p, count - 60, f'{count}', ha="center", fontsize=10, fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# ----------------------------------------
#  Class  Count  Percentage
# Defect   2394   48.648649
# Normal   2527   51.351351
# ----------------------------------------

# %%
import random

np.random.seed(42)
normal_indices = np.where(y == 'Normal')[0]
defect_indices = np.where(y == 'Defect')[0]

random_normal_idx = np.random.choice(normal_indices, 3, replace=False)
random_defect_idx = np.random.choice(defect_indices, 3, replace=False)

fig, axes = plt.subplots(3, 2, figsize=(15, 10), sharex=True, sharey=True)

for i in range(3):
    n_idx = random_normal_idx[i]
    axes[i, 0].plot(X[n_idx, 0, :], color="royalblue", linewidth=1, alpha=0.8)
    axes[i, 0].set_title(f"Normal Sample #{i+1} (Index: {n_idx})", fontsize=11, fontweight='bold', color='navy')
    axes[i, 0].set_ylabel("Normalized Value")
    axes[i, 0].grid(True, linestyle="--", alpha=0.5)
    
    d_idx = random_defect_idx[i]
    axes[i, 1].plot(X[d_idx, 0, :], color="crimson", linewidth=1, alpha=0.8)
    axes[i, 1].set_title(f"Defective Sample #{i+1} (Index: {d_idx})", fontsize=11, fontweight='bold', color='darkred')
    axes[i, 1].grid(True, linestyle="--", alpha=0.5)

axes[2, 0].set_xlabel("Time Steps (0 to 500)", fontsize=11)
axes[2, 1].set_xlabel("Time Steps (0 to 500)", fontsize=11)

plt.suptitle("ERandom Raw Signal Comparison", fontsize=15, fontweight='bold', y=0.98)
plt.tight_layout()
plt.show()

# %%
try:
    from aeon.classification.distance_based import KNeighborsTimeSeriesClassifier
    from aeon.classification.interval_based import TimeSeriesForestClassifier, DrCIFClassifier
    from aeon.classification.dictionary_based import BOSSEnsemble, WEASEL_V2
    from aeon.classification.convolution_based import MiniRocketClassifier
    from aeon.classification.hybrid import HIVECOTEV2
    from aeon.classification.deep_learning import InceptionTimeClassifier
    print("TSC model imported")
    
except ImportError as e:
    print("Error.")
    print(f"Error Message: {e}")
# Out:
# TSC model imported

# %%
import tensorflow as tf
print(f"GPU: {len(tf.config.list_physical_devices('GPU'))}")
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# GPU: 0

# %%
import os

n_cores = os.cpu_count()
print(f"💻 현재 시스템의 CPU 코어 수: {n_cores}개 -> 모든 코어를 연산에 동원합니다 (`n_jobs=-1`).")

models_dict = {}

models_dict['KNN_DTW'] = KNeighborsTimeSeriesClassifier(
    distance="dtw", 
    n_neighbors=1, 
    n_jobs=-1
)

models_dict['TimeSeriesForest'] = TimeSeriesForestClassifier(
    n_estimators=100, 
    random_state=42, 
    n_jobs=-1
)

models_dict['DrCIF'] = DrCIFClassifier(
    n_estimators=50,      # CPU 연산량 경감을 위해 50개로 최적화
    random_state=42, 
    n_jobs=-1
)

models_dict['BOSSEnsemble'] = BOSSEnsemble(
    max_ensemble_size=5,  # 앙상블 크기를 제한하여 메모리 및 CPU 부하 방지
    random_state=42,
    n_jobs=-1
)

models_dict['WEASEL_V2'] = WEASEL_V2(
    random_state=42,
    n_jobs=-1
)

models_dict['MiniRocket'] = MiniRocketClassifier(
    random_state=42, 
    n_jobs=-1
)

models_dict['InceptionTime'] = InceptionTimeClassifier(
    n_epochs=15, 
    batch_size=64,
    random_state=42
)

# 6. Hybrid (최종 보스 메타 앙상블)
# CPU 환경에서 무한정 대기하는 것을 막기 위해 '최대 학습 시간(분)' 강제 제한 옵션을 부여합니다.
models_dict['HIVECOTEV2'] = HIVECOTEV2(
    time_limit_in_minutes=10, # 최대 10분만 학습하고 그 안에서 최선의 결과 추출
    random_state=42,
    n_jobs=-1
)

print("\n⚙️ 8대 모델 객체 정의 완료:")
for name in models_dict.keys():
    print(f"   ▶ {name} (준비 완료)")
# Out:
# 💻 현재 시스템의 CPU 코어 수: 24개 -> 모든 코어를 연산에 동원합니다 (`n_jobs=-1`).
#
# ⚙️ 8대 모델 객체 정의 완료:
#    ▶ KNN_DTW (준비 완료)
#    ▶ TimeSeriesForest (준비 완료)
#    ▶ DrCIF (준비 완료)
#    ▶ BOSSEnsemble (준비 완료)
#    ▶ WEASEL_V2 (준비 완료)
#    ▶ MiniRocket (준비 완료)
#    ▶ InceptionTime (준비 완료)
#    ▶ HIVECOTEV2 (준비 완료)

# %%
import warnings
warnings.filterwarnings('ignore')  # 수많은 모델들의 Deprecation 경고문 제거로 가독성 확보

# 결과를 저장할 빈 리스트 생성
benchmark_results = []

print(f"{'Model Name':<20} | {'Train Time':<12} | {'Accuracy':<10} | {'Precision':<10} | {'Recall':<10} | {'F1-Score':<10}")
print("-" * 85)

for name, model in models_dict.items():
    try:
        # 1) 학습 시작 시간 기록
        start_train = time.time()
        
        # 2) 모델 학습 (Fit)
        model.fit(X_train, y_train)
        
        # 3) 학습 소요 시간 계산
        train_time = time.time() - start_train
        
        # 4) 테스트 데이터 예측 (Predict)
        y_pred = model.predict(X_test)
        
        # 5) 다각적 학술 지표 산출 ('Normal'과 'Defect' 중 'Defect'를 이상치 탐지 타겟(Positive)으로 설정)
        # 만약 분류 지표에서 문자열 오류를 방지하기 위해 pos_label='Defect' 지정
        acc = accuracy_score(y_test, y_pred)
        prec = precision_score(y_test, y_pred, pos_label='Defect', zero_division=0)
        rec = recall_score(y_test, y_pred, pos_label='Defect', zero_division=0)
        f1 = f1_score(y_test, y_pred, pos_label='Defect', zero_division=0)
        
        # 6) 콘솔에 즉시 결과 출력 (실시간 진행 상황 확인용)
        print(f"{name:<20} | {train_time:>10.2f}s | {acc:>9.4f} | {prec:>9.4f} | {rec:>9.4f} | {f1:>9.4f}")
        
        # 7) 데이터프레임 변환용 리스트에 딕셔너리 형태로 저장
        benchmark_results.append({
            'Model': name,
            'Train Time (sec)': round(train_time, 2),
            'Accuracy': round(acc, 4),
            'Precision': round(prec, 4),
            'Recall': round(rec, 4),
            'F1-Score': round(f1, 4),
            'y_pred': y_pred
        })
        
    except Exception as e:
        print(f"❌ {name} 학습 중 에러 발생: {str(e)}")
        continue

print("-" * 85)
print("✅ 모든 8대 모델의 벤치마크 학습 및 평가가 완료되었습니다!")

# 8) 최종 결과를 판다스 데이터프레임으로 변환 및 정렬 (정확도 순)
df_results = pd.DataFrame(benchmark_results)
df_results_sorted = df_results.sort_values(by='Accuracy', ascending=False).reset_index(drop=True)
# Out:
# 🚀 8대 시계열 분류(TSC) 알고리즘 벤치마크 대장정을 시작합니다.
# 💻 CPU 멀티프로세싱 기반으로 작동하므로 모델에 따라 수 분이 소요될 수 있습니다.
#
# Model Name           | Train Time   | Accuracy   | Precision  | Recall     | F1-Score
# -------------------------------------------------------------------------------------

# %%
# ==============================================================================
# 4.7 벤치마크 스코어보드 시각화 (정확도 기준 내림차순 정렬)
# ==============================================================================
print("📊 [Table 1] FordA 자동차 엔진 소음 분류 8대 알고리즘 벤치마크 최종 결과")
display(df_results_sorted.drop(columns=['y_pred'])) # 가독성을 위해 예측값 배열 열은 숨기고 출력
